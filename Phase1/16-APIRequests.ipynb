# %% [markdown]
# # APIs - Gathering Data Using Requests

# %% [markdown]
# ## The Many Use Cases For APIs
#
# APIs can be used for many things - much more than just retrieving information. Twilio has an API that allows you to write a script to send text messages to people. GitHub has an API for creating new repositories. Many services have APIs allowing computers to automate tasks that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database, or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ## Limitations of APIs
#
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
#
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information you might want through their API
#
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.
#
# What else is good to know? **Every API is different!** There are some standards out there in terms of documentation and usage... but it's like the wild west - rapid expansion with few rules.
#
# With all that out of the way - Let's take a look at the `requests` library and its uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# > "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor."
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ### Types of Requests
#
# We will mostly use GET requests in order to get data, but there are other options.
#
# ![CRUD image from IntelliPaat](https://intellipaat.com/mediaFiles/2015/08/MongoDB-CRUD-operations.jpg)
#
# That's right - CRUD summarizes the kinds of requests you can make with most APIs.
#
# Let's say you are looking at an API for a car rental company like Hertz or Zipcar - the following different requests could generate these different responses:
#
# | Request               | Result                               | In CRUD Terms |
# | --------------------- | ------------------------------------ | ------------- |
# | GET /stores/          | User sees the list of stores         | Read          |
# | GET /rentals/         | User sees the history of car rentals | Read          |
# | POST /rentals/        | User rents a car                     | Create        |
# | PUT /rentals/{id}/    | User changes destination store       | Update        |
# | DELETE /rentals/{id}/ | User cancels the active car rental   | Delete        |

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# Don't already have the library? Uncomment the below code and install it locally
#!pip install requests

# %%
# Create a GET request, then check the type of object

r = requests.get('https://api.github.com/events') 
type(r)
# Out:
# requests.models.Response

# %%
# So what does this look like?
r.text
# Out:
# '[{"id":"22183771748","type":"PushEvent","actor":{"id":99292913,"login":"Googluu","display_login":"Googluu","gravatar_id":"","url":"https://api.github.com/users/Googluu","avatar_url":"https://avatars.githubusercontent.com/u/99292913?"},"repo":{"id":500454844,"name":"Googluu/project","url":"https://api.github.com/repos/Googluu/project"},"payload":{"push_id":10083787270,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"b20b2430b2665a1b0bc4c2d63e5cf8974fe932a8","before":"c7bbd063f1dae6ccc39656c5e96aad7c32b72322","commits":[{"sha":"b20b2430b2665a1b0bc4c2d63e5cf8974fe932a8","author":{"email":"99292913+Googluu@users.noreply.github.com","name":"Gloogluu"},"message":"Create README.md","distinct":true,"url":"https://api.github.com/repos/Googluu/project/commits/b20b2430b2665a1b0bc4c2d63e5cf8974fe932a8"}]},"public":true,"created_at":"2022-06-06T15:36:46Z"},{"id":"22183771779","type":"CreateEvent","actor":{"id":66597192,"login":"Srinja333","display_login":"Srinja333","gravatar_id":"","url":"https://api.github.com/users/Srinja333","avatar_url":"https://avatars.githubusercontent.com/u/66597192?"},"repo":{"id":500491719,"name":"Srinja333/Tour-and-Travel-Fully-Responsive-Website","url":"https://api.github.com/repos/Srinja333/Tour-and-Travel-Fully-Responsive-Website"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","description":"I have created this website by using HTML,CSS,PHP AND JAVASCRIPT","pusher_type":"user"},"public":true,"created_at":"2022-06-06T15:36:46Z"},{"id":"22183771765","type":"DeleteEvent","actor":{"id":73036580,"login":"Rajpreetgill","display_login":"Rajpreetgill","gravatar_id":"","url":"https://api.github.com/users/Rajpreetgill","avatar_url":"https://avatars.githubusercontent.com/u/73036580?"},"repo":{"id":348396219,"name":"zowe/vscode-extension-for-cics","url":"https://api.github.com/repos/zowe/vscode-extension-for-cics"},"payload":{"ref":"lower-case-fix","ref_type":"branch","pusher_type":"user"},"public":true,"created_at":"2022-06-06T15:36:46Z","org":{"id":41340454,"login":"zowe","gravatar_id":"","url":"https://api.github.com/orgs/zowe","avatar_url":"https://avatars.githubusercontent.com/u/41340454?"}},{"id":"22183771718","type":"PullRequestReviewCommentEvent","actor":{"id":55816945,"login":"gusthawojunkes","display_login":"gusthawojunkes","gravatar_id":"","url":"https://api.github.com/users/gusthawojunkes","avatar_url":"https://avatars.githubusercontent.com/u/55816945?"},"repo":{"id":497044018,"name":"gusthawojunkes/feedy","url":"https://api.github.com/repos/gusthawojunkes/feedy"},"payload":{"action":"created","comment":{"url":"https://api.github.com/repos/gusthawojunkes/feedy/pulls/comments/890275529","pull_request_review_id":996782667,"id":890275529,"node_id":"PRRC_kwDOHaBKMs41EIbJ","diff_hunk":"@@ -97,18 +55,38 @@ export default defineComponent({\\n             product: {},\\n             quantity: 0,\\n         },\\n+        orderConfirmation: {\\n+            title: \'Deseja confirmar o Pedido?\',\\n+            model: true,\\n+        },\\n     }),\\n     methods: {\\n         openItemModal(newItem) {\\n             this.dialog = true;\\n             this.item.product = newItem;\\n         },\\n-        incrementItem() {\\n-            this.item.quantity = this.item.quantity + 1;\\n+        incrementItem(product) {\\n+            if (this.items.find((item) => item.product.uid === product.uid)) {\\n+                this.items.find((item) => item.product.uid === product.uid).quantity++;\\n+            } else {\\n+                this.items.push({\\n+                    product,\\n+                    quantity: 1,","path":"src/views/Order.vue","position":133,"original_position":133,"commit_id":"23618e852a73623e3005341674af2890c0297acf","original_commit_id":"23618e852a73623e3005341674af2890c0297acf","user":{"login":"gusthawojunkes","id":55816945,"node_id":"MDQ6VXNlcjU1ODE2OTQ1","avatar_url":"https://avatars.githubusercontent.com/u/55816945?v=4","gravatar_id":"","url":"https://api.github.com ...

# %% [markdown]
# ![Oh good heavens gif, from gfycat](https://thumbs.gfycat.com/ColdAmbitiousDogwoodtwigborer-size_restricted.gif)

# %% [markdown]
# Obviously you're never going to just scan that quickly for any data you need, we need to wrangle that response to make it usable.
#
# But first, let's look at some of the other attributes of `requests.models.Response` objects.
#
# We can check out all of the attributes [here](https://2.python-requests.org//en/v0.10.6/api/) in the documentation.

# %%
# Another attribute, what does this show us?
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Mon, 06 Jun 2022 15:41:47 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"125d47c71cdad0bbcc9c41d0df46ecfbd1d10820ea4fcd36f90efd658a185c65"', 'Last-Modified': 'Mon, 06 Jun 2022 15:36:46 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1654533711', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '1', 'Accept-Ranges': 'bytes', 'Content-Length': '36472', 'X-GitHub-Request-Id': 'D58E:8E43:2E08F59:86A36A6:629E203F'}

# %% [markdown]
# ### Checking out the status of your request

# %%
# Another attribute
r.status_code
# Out:
# 200

# %% [markdown]
# ### [Types of status codes](https://http.cat/)
#
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)
#
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %%
# Get status code for a "broken" link

r_broken = requests.get('https://api.github.com/fake-ending')
r_broken.status_code
# Out:
# 404

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception
# - A Timeout exception will be raised if a request times out
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %%
# Going back to our working request - how does this look, compared to text?
r.json()
# Out:
# [{'id': '22183771748',
#   'type': 'PushEvent',
#   'actor': {'id': 99292913,
#    'login': 'Googluu',
#    'display_login': 'Googluu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Googluu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99292913?'},
#   'repo': {'id': 500454844,
#    'name': 'Googluu/project',
#    'url': 'https://api.github.com/repos/Googluu/project'},
#   'payload': {'push_id': 10083787270,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b20b2430b2665a1b0bc4c2d63e5cf8974fe932a8',
#    'before': 'c7bbd063f1dae6ccc39656c5e96aad7c32b72322',
#    'commits': [{'sha': 'b20b2430b2665a1b0bc4c2d63e5cf8974fe932a8',
#      'author': {'email': '99292913+Googluu@users.noreply.github.com',
#       'name': 'Gloogluu'},
#      'message': 'Create README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Googluu/project/commits/b20b2430b2665a1b0bc4c2d63e5cf8974fe932a8'}]},
#   'public': True,
#   'created_at': '2022-06-06T15:36:46Z'},
#  {'id': '22183771779',
#   'type': 'CreateEvent',
#   'actor': {'id': 66597192,
#    'login': 'Srinja333',
#    'display_login': 'Srinja333',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Srinja333',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66597192?'},
#   'repo': {'id': 500491719,
#    'name': 'Srinja333/Tour-and-Travel-Fully-Responsive-Website',
#    'url': 'https://api.github.com/repos/Srinja333/Tour-and-Travel-Fully-Responsive-Website'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'I have created this website by using HTML,CSS,PHP AND JAVASCRIPT',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-06-06T15:36:46Z'},
#  {'id': '22183771765',
#   'type': 'DeleteEvent',
#   'actor': {'id': 73036580,
#    'login': 'Rajpreetgill',
#    'display_login': 'Rajpreetgill',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rajpreetgill',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73036580?'},
#   'repo': {'id': 348396219,
#    'name': 'zowe/vscode-extension-for-cics',
#    'url': 'https://api.github.com/repos/zowe/vscode-extension-for-cics'},
#   'payload': {'ref': 'lower-case-fix',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-06-06T15:36:46Z',
#   'org': {'id': 41340454,
#    'login': 'zowe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/zowe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41340454?'}},
#  {'id': '22183771718',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 55816945,
#    'login': 'gusthawojunkes',
#    'display_login': 'gusthawojunkes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gusthawojunkes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55816945?'},
#   'repo': {'id': 497044018,
#    'name': 'gusthawojunkes/feedy',
#    'url': 'https://api.github.com/repos/gusthawojunkes/feedy'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/comments/890275529',
#     'pull_request_review_id': 996782667,
#     'id': 890275529,
#     'node_id': 'PRRC_kwDOHaBKMs41EIbJ',
#     'diff_hunk': "@@ -97,18 +55,38 @@ export default defineComponent({\n             product: {},\n             quantity: 0,\n         },\n+        orderConfirmation: {\n+            title: 'Deseja confirmar o Pedido?',\n+            model: true,\n+        },\n     }),\n     methods: {\n         openItemModal(newItem) {\n             this.dialog = true;\n             this.item.product = newItem;\n         },\n-        incrementItem() {\n-            this.item.quantity = this.item.quantity + 1;\n+        incrementItem(product) {\n+            if (this.items.find((item) => item.product.uid === product.uid)) {\n+                this.items.find((item) => item.product.uid === product.uid).quantity++;\n+            } else {\n+                this.items.push({\n+                    product,\n+                    quantity: 1,",
#     'path': 'src/views/Order.vue',
#     'position': 133,
#     'original_position': 133,
#     'commit_id': '23618e852a73623e3005341674af2890c0297acf',
#     'original_commit_id': '23618e852a73623e3005341674af2890c0297acf',
#     'user': {'login': 'gusthawojunkes',
#      'id': 55816945,
#      'node_id': 'MDQ6VXNlcjU1ODE2OTQ1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/55816945?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gusthawojunkes',
#      'html_url': 'https://github.com/gusthawojunkes',
#      'followers_url': 'https://api.github.com/users/gusthawojunkes/followers',
#      'following_url': 'https://api.github.com/users/gusthawojunkes/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gusthawojunkes/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gusthawojunkes/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gusthawojunkes/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gusthawojunkes/orgs',
#      'repos_url': 'https://api.github.com/users/gusthawojunkes/repos',
#      'events_url': 'https://api.github.com/users/gusthawojunkes/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gusthawojunkes/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Você adiciona 1 fixo sempre? Eu não posso escolhar a quantidade de produtos que eu quero?',
#     'created_at': '2022-06-06T15:33:18Z',
#     'updated_at': '2022-06-06T15:36:45Z',
#     'html_url': 'https://github.com/gusthawojunkes/feedy/pull/6#discussion_r890275529',
#     'pull_request_url': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/6',
#     'author_association': 'OWNER',
#     '_links': {'self': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/comments/890275529'},
#      'html': {'href': 'https://github.com/gusthawojunkes/feedy/pull/6#discussion_r890275529'},
#      'pull_request': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/6'}},
#     'reactions': {'url': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/comments/890275529/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'start_line': None,
#     'original_start_line': None,
#     'start_side': None,
#     'line': 74,
#     'original_line': 74,
#     'side': 'RIGHT'},
#    'pull_request': {'url': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/6',
#     'id': 958527546,
#     'node_id': 'PR_kwDOHaBKMs45Ifg6',
#     'html_url': 'https://github.com/gusthawojunkes/feedy/pull/6',
#     'diff_url': 'https://github.com/gusthawojunkes/feedy/pull/6.diff',
#     'patch_url': 'https://github.com/gusthawojunkes/feedy/pull/6.patch',
#     'issue_url': 'https://api.github.com/repos/gusthawojunkes/feedy/issues/6',
#     'number': 6,
#     'state': 'open',
#     'locked': False,
#     'title': 'Ajuste em telas e em regras',
#     'user': {'login': 'Nathan-Stuber-Antunes',
#      'id': 51455214,
#      'node_id': 'MDQ6VXNlcjUxNDU1MjE0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/51455214?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Nathan-Stuber-Antunes',
#      'html_url': 'https://github.com/Nathan-Stuber-Antunes',
#      'followers_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/followers',
#      'following_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/orgs',
#      'repos_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/repos',
#      'events_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Realizado a estilização de todas as telas da aplicação.\r\nCor usada: #009688\r\nCriada uma logo, caso queira alterar, só falar!\r\n![LogoFeedy](https://user-images.githubusercontent.com/51455214/172074709-d6369ee7-6fff-45ff-ae58-c3021e20fee8.png)\r\n\r\nHome:\r\nRealizado a estilização.\r\nIncluído a AppBar para modo Desktop, deixando a navegação pelos botões inferiores para o Mobile.\r\nIncluída validação de pedido em Aberto, pelo pedido gravado no sessionStorage.\r\n\r\nPedido em aberto:\r\nRealizado a estilização.\r\nIncluído as seguintes funcionalidades:\r\n- O usuário pode inserir ou remover itens ao carrinho pelos botões com ícones de Soma e Subtração.\r\n- Os itens que ele incluir ficam marcados com uma Tag verde de "Adicionado ao Pedido".\r\n- Ao incluir o primeiro unidade do item, uma notificação de inclusão é executada.\r\n- Ao excluir a última unidade do item, uma notificação de inclusão é executada para alertar o usuário sobre a remoção total daquele item. E a Tag "Adicionado ao Pedido" é removida.\r\n- Para salvar as alterações no Pedido o usuário deve clicar no botão verde de "Confirmar Pedido"\r\n- Ao confirmar as alterações uma notificação é ativada.\r\n- Ao criar e alterar o pedido em Aberto as informações dele são enviadas ao Firebase e armazenadas no session storage.\r\nFalta a inclusão da descrição  na exibição dos produtos, pois não achei uma forma legal de colocar em tela!\r\n\r\n\r\nHistórico de Pedidos\r\nRealizado a estilização.\r\nAjustada a exibição do histórico, para começar do mais novo. \r\nPor hora esta sendo realizada a obtenção te dos os pedidos do bando de dados sem filtro pela mesa do usuário.\r\n\r\nConfiguração de Pedidos\r\nRealizado a estilização.\r\nIncluído a exibição da descrição por meio de um botão, com ícone de uma seta para baixo, que abre uma expansão do card do produto.\r\n\r\n404\r\nAjustado os textos e formatações, da tela que é exibida caso seja especificada uma rota não configurada.\r\n\r\nCreio ter descrito o meu desenvolvimento, caso encontre algo que fiz e que não esta aqui me de um toque.',
#     'created_at': '2022-06-05T23:36:46Z',
#     'updated_at': '2022-06-06T15:36:45Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': {'login': 'Nathan-Stuber-Antunes',
#      'id': 51455214,
#      'node_id': 'MDQ6VXNlcjUxNDU1MjE0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/51455214?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Nathan-Stuber-Antunes',
#      'html_url': 'https://github.com/Nathan-Stuber-Antunes',
#      'followers_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/followers',
#      'following_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/orgs',
#      'repos_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/repos',
#      'events_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'Nathan-Stuber-Antunes',
#       'id': 51455214,
#       'node_id': 'MDQ6VXNlcjUxNDU1MjE0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/51455214?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Nathan-Stuber-Antunes',
#       'html_url': 'https://github.com/Nathan-Stuber-Antunes',
#       'followers_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/followers',
#       'following_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/orgs',
#       'repos_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/repos',
#       'events_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Nathan-Stuber-Antunes/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/6/commits',
#     'review_comments_url': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/6/comments',
#     'review_comment_url': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/gusthawojunkes/feedy/issues/6/comments',
#     'statuses_url': 'https://api.github.com/repos/gusthawojunkes/feedy/statuses/23618e852a73623e3005341674af2890c0297acf',
#     'head': {'label': 'gusthawojunkes:ft-ajuse-nas-telas',
#      'ref': 'ft-ajuse-nas-telas',
#      'sha': '23618e852a73623e3005341674af2890c0297acf',
#      'user': {'login': 'gusthawojunkes',
#       'id': 55816945,
#       'node_id': 'MDQ6VXNlcjU1ODE2OTQ1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/55816945?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/gusthawojunkes',
#       'html_url': 'https://github.com/gusthawojunkes',
#       'followers_url': 'https://api.github.com/users/gusthawojunkes/followers',
#       'following_url': 'https://api.github.com/users/gusthawojunkes/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/gusthawojunkes/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/gusthawojunkes/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/gusthawojunkes/subscriptions',
#       'organizations_url': 'https://api.github.com/users/gusthawojunkes/orgs',
#       'repos_url': 'https://api.github.com/users/gusthawojunkes/repos',
#       'events_url': 'https://api.github.com/users/gusthawojunkes/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/gusthawojunkes/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 497044018,
#       'node_id': 'R_kgDOHaBKMg',
#       'name': 'feedy',
#       'full_name': 'gusthawojunkes/feedy',
#       'private': False,
#       'owner': {'login': 'gusthawojunkes',
#        'id': 55816945,
#        'node_id': 'MDQ6VXNlcjU1ODE2OTQ1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/55816945?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/gusthawojunkes',
#        'html_url': 'https://github.com/gusthawojunkes',
#        'followers_url': 'https://api.github.com/users/gusthawojunkes/followers',
#        'following_url': 'https://api.github.com/users/gusthawojunkes/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/gusthawojunkes/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/gusthawojunkes/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/gusthawojunkes/subscriptions',
#        'organizations_url': 'https://api.github.com/users/gusthawojunkes/orgs',
#        'repos_url': 'https://api.github.com/users/gusthawojunkes/repos',
#        'events_url': 'https://api.github.com/users/gusthawojunkes/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/gusthawojunkes/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/gusthawojunkes/feedy',
#       'description': 'Feedy Application',
#       'fork': False,
#       'url': 'https://api.github.com/repos/gusthawojunkes/feedy',
#       'forks_url': 'https://api.github.com/repos/gusthawojunkes/feedy/forks',
#       'keys_url': 'https://api.github.com/repos/gusthawojunkes/feedy/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/gusthawojunkes/feedy/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/gusthawojunkes/feedy/teams',
#       'hooks_url': 'https://api.github.com/repos/gusthawojunkes/feedy/hooks',
#       'issue_events_url': 'https://api.github.com/repos/gusthawojunkes/feedy/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/gusthawojunkes/feedy/events',
#       'assignees_url': 'https://api.github.com/repos/gusthawojunkes/feedy/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/gusthawojunkes/feedy/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/gusthawojunkes/feedy/tags',
#       'blobs_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/gusthawojunkes/feedy/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/gusthawojunkes/feedy/languages',
#       'stargazers_url': 'https://api.github.com/repos/gusthawojunkes/feedy/stargazers',
#       'contributors_url': 'https://api.github.com/repos/gusthawojunkes/feedy/contributors',
#       'subscribers_url': 'https://api.github.com/repos/gusthawojunkes/feedy/subscribers',
#       'subscription_url': 'https://api.github.com/repos/gusthawojunkes/feedy/subscription',
#       'commits_url': 'https://api.github.com/repos/gusthawojunkes/feedy/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/gusthawojunkes/feedy/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/gusthawojunkes/feedy/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/gusthawojunkes/feedy/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/gusthawojunkes/feedy/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/gusthawojunkes/feedy/merges',
#       'archive_url': 'https://api.github.com/repos/gusthawojunkes/feedy/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/gusthawojunkes/feedy/downloads',
#       'issues_url': 'https://api.github.com/repos/gusthawojunkes/feedy/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/gusthawojunkes/feedy/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/gusthawojunkes/feedy/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/gusthawojunkes/feedy/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/gusthawojunkes/feedy/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/gusthawojunkes/feedy/deployments',
#       'created_at': '2022-05-27T15:17:46Z',
#       'updated_at': '2022-05-29T17:53:58Z',
#       'pushed_at': '2022-06-05T23:36:46Z',
#       'git_url': 'git://github.com/gusthawojunkes/feedy.git',
#       'ssh_url': 'git@github.com:gusthawojunkes/feedy.git',
#       'clone_url': 'https://github.com/gusthawojunkes/feedy.git',
#       'svn_url': 'https://github.com/gusthawojunkes/feedy',
#       'homepage': '',
#       'size': 369,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Vue',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['firebase-firestore',
#        'vue',
#        'vue-router',
#        'vuejs3',
#        'vuetify3'],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'gusthawojunkes:master',
#      'ref': 'master',
#      'sha': '49f87b16d475b6b9684c99905d7ad2ca76967d23',
#      'user': {'login': 'gusthawojunkes',
#       'id': 55816945,
#       'node_id': 'MDQ6VXNlcjU1ODE2OTQ1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/55816945?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/gusthawojunkes',
#       'html_url': 'https://github.com/gusthawojunkes',
#       'followers_url': 'https://api.github.com/users/gusthawojunkes/followers',
#       'following_url': 'https://api.github.com/users/gusthawojunkes/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/gusthawojunkes/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/gusthawojunkes/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/gusthawojunkes/subscriptions',
#       'organizations_url': 'https://api.github.com/users/gusthawojunkes/orgs',
#       'repos_url': 'https://api.github.com/users/gusthawojunkes/repos',
#       'events_url': 'https://api.github.com/users/gusthawojunkes/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/gusthawojunkes/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 497044018,
#       'node_id': 'R_kgDOHaBKMg',
#       'name': 'feedy',
#       'full_name': 'gusthawojunkes/feedy',
#       'private': False,
#       'owner': {'login': 'gusthawojunkes',
#        'id': 55816945,
#        'node_id': 'MDQ6VXNlcjU1ODE2OTQ1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/55816945?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/gusthawojunkes',
#        'html_url': 'https://github.com/gusthawojunkes',
#        'followers_url': 'https://api.github.com/users/gusthawojunkes/followers',
#        'following_url': 'https://api.github.com/users/gusthawojunkes/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/gusthawojunkes/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/gusthawojunkes/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/gusthawojunkes/subscriptions',
#        'organizations_url': 'https://api.github.com/users/gusthawojunkes/orgs',
#        'repos_url': 'https://api.github.com/users/gusthawojunkes/repos',
#        'events_url': 'https://api.github.com/users/gusthawojunkes/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/gusthawojunkes/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/gusthawojunkes/feedy',
#       'description': 'Feedy Application',
#       'fork': False,
#       'url': 'https://api.github.com/repos/gusthawojunkes/feedy',
#       'forks_url': 'https://api.github.com/repos/gusthawojunkes/feedy/forks',
#       'keys_url': 'https://api.github.com/repos/gusthawojunkes/feedy/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/gusthawojunkes/feedy/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/gusthawojunkes/feedy/teams',
#       'hooks_url': 'https://api.github.com/repos/gusthawojunkes/feedy/hooks',
#       'issue_events_url': 'https://api.github.com/repos/gusthawojunkes/feedy/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/gusthawojunkes/feedy/events',
#       'assignees_url': 'https://api.github.com/repos/gusthawojunkes/feedy/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/gusthawojunkes/feedy/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/gusthawojunkes/feedy/tags',
#       'blobs_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/gusthawojunkes/feedy/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/gusthawojunkes/feedy/languages',
#       'stargazers_url': 'https://api.github.com/repos/gusthawojunkes/feedy/stargazers',
#       'contributors_url': 'https://api.github.com/repos/gusthawojunkes/feedy/contributors',
#       'subscribers_url': 'https://api.github.com/repos/gusthawojunkes/feedy/subscribers',
#       'subscription_url': 'https://api.github.com/repos/gusthawojunkes/feedy/subscription',
#       'commits_url': 'https://api.github.com/repos/gusthawojunkes/feedy/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/gusthawojunkes/feedy/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/gusthawojunkes/feedy/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/gusthawojunkes/feedy/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/gusthawojunkes/feedy/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/gusthawojunkes/feedy/merges',
#       'archive_url': 'https://api.github.com/repos/gusthawojunkes/feedy/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/gusthawojunkes/feedy/downloads',
#       'issues_url': 'https://api.github.com/repos/gusthawojunkes/feedy/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/gusthawojunkes/feedy/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/gusthawojunkes/feedy/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/gusthawojunkes/feedy/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/gusthawojunkes/feedy/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/gusthawojunkes/feedy/deployments',
#       'created_at': '2022-05-27T15:17:46Z',
#       'updated_at': '2022-05-29T17:53:58Z',
#       'pushed_at': '2022-06-05T23:36:46Z',
#       'git_url': 'git://github.com/gusthawojunkes/feedy.git',
#       'ssh_url': 'git@github.com:gusthawojunkes/feedy.git',
#       'clone_url': 'https://github.com/gusthawojunkes/feedy.git',
#       'svn_url': 'https://github.com/gusthawojunkes/feedy',
#       'homepage': '',
#       'size': 369,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Vue',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['firebase-firestore',
#        'vue',
#        'vue-router',
#        'vuejs3',
#        'vuetify3'],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/6'},
#      'html': {'href': 'https://github.com/gusthawojunkes/feedy/pull/6'},
#      'issue': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/issues/6'},
#      'comments': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/issues/6/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/6/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/6/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/statuses/23618e852a73623e3005341674af2890c0297acf'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2022-06-06T15:33:18Z'},
#  {'id': '22183771709',
#   'type': 'CreateEvent',
#   'actor': {'id': 4939753,
#    'login': 'jitsi-jenkins',
#    'display_login': 'jitsi-jenkins',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jitsi-jenkins',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4939753?'},
#   'repo': {'id': 74407073,
#    'name': 'jitsi/jitsi-meet-debian-meta',
#    'url': 'https://api.github.com/repos/jitsi/jitsi-meet-debian-meta'},
#   'payload': {'ref': 'jitsi-meet_7389',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': 'Jitsi Meet meta debian package',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-06-06T15:36:46Z',
#   'org': {'id': 3671647,
#    'login': 'jitsi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/jitsi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3671647?'}},
#  {'id': '22183771768',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 104365663,
#    'name': 'pulumi/docs',
#    'url': 'https://api.github.com/repos/pulumi/docs'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/pulumi/docs/issues/7623',
#     'repository_url': 'https://api.github.com/repos/pulumi/docs',
#     'labels_url': 'https://api.github.com/repos/pulumi/docs/issues/7623/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/pulumi/docs/issues/7623/comments',
#     'events_url': 'https://api.github.com/repos/pulumi/docs/issues/7623/events',
#     'html_url': 'https://github.com/pulumi/docs/pull/7623',
#     'id': 1261973932,
#     'node_id': 'PR_kwDOBjh-X845LIdp',
#     'number': 7623,
#     'title': 'Update Hugo modules',
#     'user': {'login': 'pulumi-bot',
#      'id': 30351955,
#      'node_id': 'MDQ6VXNlcjMwMzUxOTU1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/30351955?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pulumi-bot',
#      'html_url': 'https://github.com/pulumi-bot',
#      'followers_url': 'https://api.github.com/users/pulumi-bot/followers',
#      'following_url': 'https://api.github.com/users/pulumi-bot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pulumi-bot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pulumi-bot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pulumi-bot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pulumi-bot/orgs',
#      'repos_url': 'https://api.github.com/users/pulumi-bot/repos',
#      'events_url': 'https://api.github.com/users/pulumi-bot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pulumi-bot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 2125581950,
#       'node_id': 'MDU6TGFiZWwyMTI1NTgxOTUw',
#       'url': 'https://api.github.com/repos/pulumi/docs/labels/automation/tfgen-provider-docs',
#       'name': 'automation/tfgen-provider-docs',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2022-06-06T15:05:44Z',
#     'updated_at': '2022-06-06T15:36:46Z',
#     'closed_at': '2022-06-06T15:33:08Z',
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/pulumi/docs/pulls/7623',
#      'html_url': 'https://github.com/pulumi/docs/pull/7623',
#      'diff_url': 'https://github.com/pulumi/docs/pull/7623.diff',
#      'patch_url': 'https://github.com/pulumi/docs/pull/7623.patch',
#      'merged_at': '2022-06-06T15:33:08Z'},
#     'body': 'Brings in the latest content from Hugo module repos, including:\n\n* https://github.com/pulumi/registry/commit/7ee4b3924ca7c0447a0b142d0e82109d986e6295',
#     'reactions': {'url': 'https://api.github.com/repos/pulumi/docs/issues/7623/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/pulumi/docs/issues/7623/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/pulumi/docs/issues/comments/1147589033',
#     'html_url': 'https://github.com/pulumi/docs/pull/7623#issuecomment-1147589033',
#     'issue_url': 'https://api.github.com/repos/pulumi/docs/issues/7623',
#     'id': 1147589033,
#     'node_id': 'IC_kwDOBjh-X85EZtGp',
#     'user': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2022-06-06T15:36:46Z',
#     'updated_at': '2022-06-06T15:36:46Z',
#     'author_association': 'NONE',
#     'body': 'Site previews for this pull request have been removed. ✨',
#     'reactions': {'url': 'https://api.github.com/repos/pulumi/docs/issues/comments/1147589033/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-06-06T15:36:46Z',
#   'org': {'id': 21992475,
#    'login': 'pulumi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pulumi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21992475?'}},
#  {'id': '22183771755',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 52976633,
#    'login': 'mberezin-r7',
#    'display_login': 'mberezin-r7',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mberezin-r7',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52976633?'},
#   'repo': {'id': 190435635,
#    'name': 'rapid7/insightconnect-plugins',
#    'url': 'https://api.github.com/repos/rapid7/insightconnect-plugins'},
#   'payload': {'action': 'closed',
#    'number': 1286,
#    'pull_request': {'url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/pulls/1286',
#     'id': 959244805,
#     'node_id': 'PR_kwDOC1nRM845LOoF',
#     'html_url': 'https://github.com/rapid7/insightconnect-plugins/pull/1286',
#     'diff_url': 'https://github.com/rapid7/insightconnect-plugins/pull/1286.diff',
#     'patch_url': 'https://github.com/rapid7/insightconnect-plugins/pull/1286.patch',
#     'issue_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/issues/1286',
#     'number': 1286,
#     'state': 'closed',
#     'locked': False,
#     'title': 'SOAR-9732: Recorded Future security patch',
#     'user': {'login': 'mberezin-r7',
#      'id': 52976633,
#      'node_id': 'MDQ6VXNlcjUyOTc2NjMz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/52976633?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mberezin-r7',
#      'html_url': 'https://github.com/mberezin-r7',
#      'followers_url': 'https://api.github.com/users/mberezin-r7/followers',
#      'following_url': 'https://api.github.com/users/mberezin-r7/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mberezin-r7/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mberezin-r7/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mberezin-r7/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mberezin-r7/orgs',
#      'repos_url': 'https://api.github.com/users/mberezin-r7/repos',
#      'events_url': 'https://api.github.com/users/mberezin-r7/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mberezin-r7/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "## Proposed Changes\r\n\r\n### Description\r\n\r\nDescribe the proposed changes:\r\n\r\n  - Remove unwanted strings from Recorded Future unit tests\r\n  - JIRA: https://issues.corp.rapid7.com/browse/SOAR-9732\r\n\r\n## PR Requirements\r\n\r\nDevelopers, verify you have completed the following items by checking them off:\r\n\r\n### Testing\r\n\r\n#### Unit Tests\r\n\r\nReview our documentation on [generating](https://docs.rapid7.com/insightconnect/unit-test-generation) and [writing](https://docs.rapid7.com/insightconnect/unit-test-primer) plugin unit tests\r\n\r\n- [ ] Unit tests written for any new or updated code\r\n\r\n#### In-Product Tests\r\n\r\nIf you are an InsightConnect customer or have access to an InsightConnect instance, the following in-product tests should be done:\r\n\r\n- [ ] Screenshot of job output with the plugin changes\r\n- [ ] Screenshot of the changed connection, actions, or triggers input within the InsightConnect workflow builder\r\n\r\n### Style\r\n\r\nReview the [style guide](https://docs.rapid7.com/insightconnect/style-guide/)\r\n\r\n- [ ] For dependencies, pin [OS package](https://docs.rapid7.com/insightconnect/style-guide/#dockerfile) and [Python package](https://docs.rapid7.com/insightconnect/style-guide/#requirements.txt) versions\r\n- [ ] For security, set least privileged account with ``USER nobody`` in the ``Dockerfile`` when possible\r\n- [ ] For size, use the [slim SDK images](https://docs.rapid7.com/insightconnect/sdk-guide/#sdk-guide) when possible: ``komand/python-3-37-slim-plugin`` and ``komand/python-3-37-plugin``\r\n- [ ] For error handling, use of [PluginException](https://docs.rapid7.com/insightconnect/error-handling-in-integrations/#plugin-exceptions) and [ConnectionTestException](https://docs.rapid7.com/insightconnect/error-handling-in-integrations#connection-exceptions)\r\n- [ ] For logging, use [self.logger](https://docs.rapid7.com/insightconnect/sdk-guide/#logging)\r\n- [ ] For docs, use [changelog style](https://docs.rapid7.com/insightconnect/style-guide/#changelog)\r\n- [ ] For docs, validate markdown with ``make validate`` which calls ``mdl`` to lint ``help.md``\r\n\r\n### Functional Checklist\r\n- [ ] Work fully completed\r\n- [ ] Functional\r\n  - [ ] Any new actions/triggers include JSON [test files](https://docs.rapid7.com/insightconnect/style-guide/#tests) in the `tests/` directory created with `icon-plugin run -c sample $action > tests/$action.json`\r\n  - [ ] Tests should all pass unless it's a negative test. Negative tests have a naming convention of `tests/$action_bad.json`\r\n  - [ ] Unsuccessful tests should fail by raising an exception causing the plugin to die and an object should be returned on successful test\r\n  - [ ] Add functioning test results to PR, sanitize any output if necessary\r\n    * Single action/trigger `icon-plugin run -T tests/example.json --debug --jq`\r\n    * All actions/triggers shortcut `icon-plugin run -T all --debug --jq` (use PR format at end)\r\n  - [ ] Add functioning run results to PR, sanitize any output if necessary\r\n    * Single action/trigger `icon-plugin run -R tests/example.json --debug --jq`\r\n    * All actions/triggers shortcut `icon-plugin run -R all --debug --jq` (use PR format at end)\r\n\r\n### Assessment\r\n\r\nYou must validate your work to reviewers:\r\n\r\n1. Run `make validate` and make sure everything passes\r\n2. Run the assessment tool: `icon-plugin run -A -R all -T all`. For single action validation: `icon-plugin run -A -R tests/my_action.json -T tests/my_action.json`\r\n3. Copy (`icon-plugin ... | pbcopy`) and paste the output in **a new post** on this PR\r\n4. Add required screenshots from the In-Product Tests section\r\n",
#     'created_at': '2022-06-06T15:27:00Z',
#     'updated_at': '2022-06-06T15:36:45Z',
#     'closed_at': '2022-06-06T15:36:45Z',
#     'merged_at': '2022-06-06T15:36:45Z',
#     'merge_commit_sha': '9be663a38901668cff9af60e118479e0ce5a6eb6',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/pulls/1286/commits',
#     'review_comments_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/pulls/1286/comments',
#     'review_comment_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/issues/1286/comments',
#     'statuses_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/statuses/ce85cf191b1eb75f37d3e04612ebd5e6443ef7e8',
#     'head': {'label': 'rapid7:SOAR-9732-recorded-future-sec',
#      'ref': 'SOAR-9732-recorded-future-sec',
#      'sha': 'ce85cf191b1eb75f37d3e04612ebd5e6443ef7e8',
#      'user': {'login': 'rapid7',
#       'id': 1013671,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEwMTM2NzE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1013671?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/rapid7',
#       'html_url': 'https://github.com/rapid7',
#       'followers_url': 'https://api.github.com/users/rapid7/followers',
#       'following_url': 'https://api.github.com/users/rapid7/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/rapid7/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/rapid7/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/rapid7/subscriptions',
#       'organizations_url': 'https://api.github.com/users/rapid7/orgs',
#       'repos_url': 'https://api.github.com/users/rapid7/repos',
#       'events_url': 'https://api.github.com/users/rapid7/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/rapid7/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 190435635,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTA0MzU2MzU=',
#       'name': 'insightconnect-plugins',
#       'full_name': 'rapid7/insightconnect-plugins',
#       'private': False,
#       'owner': {'login': 'rapid7',
#        'id': 1013671,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEwMTM2NzE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/1013671?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/rapid7',
#        'html_url': 'https://github.com/rapid7',
#        'followers_url': 'https://api.github.com/users/rapid7/followers',
#        'following_url': 'https://api.github.com/users/rapid7/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/rapid7/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/rapid7/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/rapid7/subscriptions',
#        'organizations_url': 'https://api.github.com/users/rapid7/orgs',
#        'repos_url': 'https://api.github.com/users/rapid7/repos',
#        'events_url': 'https://api.github.com/users/rapid7/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/rapid7/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/rapid7/insightconnect-plugins',
#       'description': 'Plugin source code for the InsightConnect SOAR product, developer documentation at https://docs.rapid7.com/insightconnect/getting-started',
#       'fork': False,
#       'url': 'https://api.github.com/repos/rapid7/insightconnect-plugins',
#       'forks_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/forks',
#       'keys_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/teams',
#       'hooks_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/hooks',
#       'issue_events_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/events',
#       'assignees_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/tags',
#       'blobs_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/languages',
#       'stargazers_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/stargazers',
#       'contributors_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/contributors',
#       'subscribers_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/subscribers',
#       'subscription_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/subscription',
#       'commits_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/merges',
#       'archive_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/rapid7/insightconnect-plugins/downloads',
# ...
#       'node_id': 'R_kgDOHaBKMg',
#       'name': 'feedy',
#       'full_name': 'gusthawojunkes/feedy',
#       'private': False,
#       'owner': {'login': 'gusthawojunkes',
#        'id': 55816945,
#        'node_id': 'MDQ6VXNlcjU1ODE2OTQ1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/55816945?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/gusthawojunkes',
#        'html_url': 'https://github.com/gusthawojunkes',
#        'followers_url': 'https://api.github.com/users/gusthawojunkes/followers',
#        'following_url': 'https://api.github.com/users/gusthawojunkes/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/gusthawojunkes/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/gusthawojunkes/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/gusthawojunkes/subscriptions',
#        'organizations_url': 'https://api.github.com/users/gusthawojunkes/orgs',
#        'repos_url': 'https://api.github.com/users/gusthawojunkes/repos',
#        'events_url': 'https://api.github.com/users/gusthawojunkes/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/gusthawojunkes/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/gusthawojunkes/feedy',
#       'description': 'Feedy Application',
#       'fork': False,
#       'url': 'https://api.github.com/repos/gusthawojunkes/feedy',
#       'forks_url': 'https://api.github.com/repos/gusthawojunkes/feedy/forks',
#       'keys_url': 'https://api.github.com/repos/gusthawojunkes/feedy/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/gusthawojunkes/feedy/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/gusthawojunkes/feedy/teams',
#       'hooks_url': 'https://api.github.com/repos/gusthawojunkes/feedy/hooks',
#       'issue_events_url': 'https://api.github.com/repos/gusthawojunkes/feedy/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/gusthawojunkes/feedy/events',
#       'assignees_url': 'https://api.github.com/repos/gusthawojunkes/feedy/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/gusthawojunkes/feedy/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/gusthawojunkes/feedy/tags',
#       'blobs_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/gusthawojunkes/feedy/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/gusthawojunkes/feedy/languages',
#       'stargazers_url': 'https://api.github.com/repos/gusthawojunkes/feedy/stargazers',
#       'contributors_url': 'https://api.github.com/repos/gusthawojunkes/feedy/contributors',
#       'subscribers_url': 'https://api.github.com/repos/gusthawojunkes/feedy/subscribers',
#       'subscription_url': 'https://api.github.com/repos/gusthawojunkes/feedy/subscription',
#       'commits_url': 'https://api.github.com/repos/gusthawojunkes/feedy/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/gusthawojunkes/feedy/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/gusthawojunkes/feedy/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/gusthawojunkes/feedy/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/gusthawojunkes/feedy/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/gusthawojunkes/feedy/merges',
#       'archive_url': 'https://api.github.com/repos/gusthawojunkes/feedy/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/gusthawojunkes/feedy/downloads',
#       'issues_url': 'https://api.github.com/repos/gusthawojunkes/feedy/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/gusthawojunkes/feedy/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/gusthawojunkes/feedy/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/gusthawojunkes/feedy/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/gusthawojunkes/feedy/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/gusthawojunkes/feedy/deployments',
#       'created_at': '2022-05-27T15:17:46Z',
#       'updated_at': '2022-05-29T17:53:58Z',
#       'pushed_at': '2022-06-05T23:36:46Z',
#       'git_url': 'git://github.com/gusthawojunkes/feedy.git',
#       'ssh_url': 'git@github.com:gusthawojunkes/feedy.git',
#       'clone_url': 'https://github.com/gusthawojunkes/feedy.git',
#       'svn_url': 'https://github.com/gusthawojunkes/feedy',
#       'homepage': '',
#       'size': 369,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Vue',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['firebase-firestore',
#        'vue',
#        'vue-router',
#        'vuejs3',
#        'vuetify3'],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'gusthawojunkes:master',
#      'ref': 'master',
#      'sha': '49f87b16d475b6b9684c99905d7ad2ca76967d23',
#      'user': {'login': 'gusthawojunkes',
#       'id': 55816945,
#       'node_id': 'MDQ6VXNlcjU1ODE2OTQ1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/55816945?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/gusthawojunkes',
#       'html_url': 'https://github.com/gusthawojunkes',
#       'followers_url': 'https://api.github.com/users/gusthawojunkes/followers',
#       'following_url': 'https://api.github.com/users/gusthawojunkes/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/gusthawojunkes/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/gusthawojunkes/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/gusthawojunkes/subscriptions',
#       'organizations_url': 'https://api.github.com/users/gusthawojunkes/orgs',
#       'repos_url': 'https://api.github.com/users/gusthawojunkes/repos',
#       'events_url': 'https://api.github.com/users/gusthawojunkes/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/gusthawojunkes/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 497044018,
#       'node_id': 'R_kgDOHaBKMg',
#       'name': 'feedy',
#       'full_name': 'gusthawojunkes/feedy',
#       'private': False,
#       'owner': {'login': 'gusthawojunkes',
#        'id': 55816945,
#        'node_id': 'MDQ6VXNlcjU1ODE2OTQ1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/55816945?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/gusthawojunkes',
#        'html_url': 'https://github.com/gusthawojunkes',
#        'followers_url': 'https://api.github.com/users/gusthawojunkes/followers',
#        'following_url': 'https://api.github.com/users/gusthawojunkes/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/gusthawojunkes/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/gusthawojunkes/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/gusthawojunkes/subscriptions',
#        'organizations_url': 'https://api.github.com/users/gusthawojunkes/orgs',
#        'repos_url': 'https://api.github.com/users/gusthawojunkes/repos',
#        'events_url': 'https://api.github.com/users/gusthawojunkes/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/gusthawojunkes/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/gusthawojunkes/feedy',
#       'description': 'Feedy Application',
#       'fork': False,
#       'url': 'https://api.github.com/repos/gusthawojunkes/feedy',
#       'forks_url': 'https://api.github.com/repos/gusthawojunkes/feedy/forks',
#       'keys_url': 'https://api.github.com/repos/gusthawojunkes/feedy/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/gusthawojunkes/feedy/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/gusthawojunkes/feedy/teams',
#       'hooks_url': 'https://api.github.com/repos/gusthawojunkes/feedy/hooks',
#       'issue_events_url': 'https://api.github.com/repos/gusthawojunkes/feedy/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/gusthawojunkes/feedy/events',
#       'assignees_url': 'https://api.github.com/repos/gusthawojunkes/feedy/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/gusthawojunkes/feedy/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/gusthawojunkes/feedy/tags',
#       'blobs_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/gusthawojunkes/feedy/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/gusthawojunkes/feedy/languages',
#       'stargazers_url': 'https://api.github.com/repos/gusthawojunkes/feedy/stargazers',
#       'contributors_url': 'https://api.github.com/repos/gusthawojunkes/feedy/contributors',
#       'subscribers_url': 'https://api.github.com/repos/gusthawojunkes/feedy/subscribers',
#       'subscription_url': 'https://api.github.com/repos/gusthawojunkes/feedy/subscription',
#       'commits_url': 'https://api.github.com/repos/gusthawojunkes/feedy/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/gusthawojunkes/feedy/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/gusthawojunkes/feedy/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/gusthawojunkes/feedy/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/gusthawojunkes/feedy/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/gusthawojunkes/feedy/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/gusthawojunkes/feedy/merges',
#       'archive_url': 'https://api.github.com/repos/gusthawojunkes/feedy/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/gusthawojunkes/feedy/downloads',
#       'issues_url': 'https://api.github.com/repos/gusthawojunkes/feedy/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/gusthawojunkes/feedy/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/gusthawojunkes/feedy/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/gusthawojunkes/feedy/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/gusthawojunkes/feedy/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/gusthawojunkes/feedy/deployments',
#       'created_at': '2022-05-27T15:17:46Z',
#       'updated_at': '2022-05-29T17:53:58Z',
#       'pushed_at': '2022-06-05T23:36:46Z',
#       'git_url': 'git://github.com/gusthawojunkes/feedy.git',
#       'ssh_url': 'git@github.com:gusthawojunkes/feedy.git',
#       'clone_url': 'https://github.com/gusthawojunkes/feedy.git',
#       'svn_url': 'https://github.com/gusthawojunkes/feedy',
#       'homepage': '',
#       'size': 369,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Vue',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['firebase-firestore',
#        'vue',
#        'vue-router',
#        'vuejs3',
#        'vuetify3'],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/6'},
#      'html': {'href': 'https://github.com/gusthawojunkes/feedy/pull/6'},
#      'issue': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/issues/6'},
#      'comments': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/issues/6/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/6/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/pulls/6/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/gusthawojunkes/feedy/statuses/23618e852a73623e3005341674af2890c0297acf'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2022-06-06T15:36:46Z'},
#  {'id': '22183771631',
#   'type': 'PushEvent',
#   'actor': {'id': 90422828,
#    'login': 'pmartisa',
#    'display_login': 'pmartisa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pmartisa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90422828?'},
#   'repo': {'id': 496673701,
#    'name': 'pmartisa/points-unknown',
#    'url': 'https://api.github.com/repos/pmartisa/points-unknown'},
#   'payload': {'push_id': 10083787245,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ea31a9dfdbd592f7770d2537a641d6f9a3776684',
#    'before': '1bd5df1e688f7fce4acf0dafcd827b3c417d61ad',
#    'commits': [{'sha': 'ea31a9dfdbd592f7770d2537a641d6f9a3776684',
#      'author': {'email': '90422828+pmartisa@users.noreply.github.com',
#       'name': 'Patricia Martínez-Sastre'},
#      'message': 'Update index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pmartisa/points-unknown/commits/ea31a9dfdbd592f7770d2537a641d6f9a3776684'}]},
#   'public': True,
#   'created_at': '2022-06-06T15:36:46Z'},
#  {'id': '22183771585',
#   'type': 'PushEvent',
#   'actor': {'id': 1511024,
#    'login': 'marabooy',
#    'display_login': 'marabooy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marabooy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1511024?'},
#   'repo': {'id': 499100378,
#    'name': 'marabooy/msgraph-metadata',
#    'url': 'https://api.github.com/repos/marabooy/msgraph-metadata'},
#   'payload': {'push_id': 10083787185,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/schemas/metadata-publishing-2022-06-06',
#    'head': 'bd5ffab805b1a574060fa6b4bbb14d0c759ef37d',
#    'before': '79080db0561b48e9fd8c5b1dd34083ee57002881',
#    'commits': [{'sha': 'bd5ffab805b1a574060fa6b4bbb14d0c759ef37d',
#      'author': {'email': '1511024+marabooy@users.noreply.github.com',
#       'name': 'David W'},
#      'message': 'Schema sync 2022-06-06 from 1.0.800.3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/marabooy/msgraph-metadata/commits/bd5ffab805b1a574060fa6b4bbb14d0c759ef37d'}]},
#   'public': True,
#   'created_at': '2022-06-06T15:36:45Z'}]

# %% [markdown]
# # Gotta Catch 'Em All! Using the Pokemon API
#
# https://pokeapi.co/
#
# Nice place to start because there's no login details or credentials to fuss with
#
# For now, just want to explore grabbing the Types of different Pokemon.
#
# Useful documentation links:
# - Pokemon endpoint: https://pokeapi.co/docs/v2#pokemon
#     - `https://pokeapi.co/api/v2/pokemon/{id or name}/`
# - Type endpoint: https://pokeapi.co/docs/v2#types
#     - `https://pokeapi.co/api/v2/type/{id or name}/`

# %% [markdown]
# ### Start by exploring the response from the Pokemon endpoint
#
# Going to start with Charmander, pokemon #4, cause he's one of my favorites
#
# <img src="https://i.pinimg.com/originals/e7/0e/d0/e70ed0b54f9230c56c2e3bd2958d68a4.jpg" alt="adorable charmander found via pinterest" width=150>
#
# [Image Source](https://www.pinterest.com/pin/419045940312305352/)

# %%
# First, what endpoint url are we using?
base_poke_url = 'https://pokeapi.co/api/v2/pokemon/'

# %%
# How does that need to adapt for charmander?
char_url = base_poke_url + '4'

# %%
# Check the status code, will this work?
requests.get(char_url).status_code
# Out:
# 200

# %%
# Now let's actually get the response
char_resp = requests.get(char_url).json()

# %%
# Let's check out some details about the response
char_resp.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'past_types', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
char_resp['id']
# Out:
# 4

# %%
char_resp['name']
# Out:
# 'charmander'

# %%
char_resp['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]

# %%
bulba_resp = requests.get(base_poke_url+'1').json()

bulba_resp['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}},
#  {'slot': 2,
#   'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]

# %% [markdown]
# #### Challenge!
#
# Let's write a function that, given a response from this API's pokemon endpoint, returns a list of the ID, name, primary type and secondary type for that pokemon.

# %%
def get_pokemon_details(poke_resp):
    '''
    inputs:
    poke_resp - expects json/dict
    
    outputs: 
    list of id, pokemon name, primary type and secondary type 
    '''
    poke_id = poke_resp['id']
    poke_name = poke_resp['name']
    primary_type = poke_resp['types'][0]['type']['name']
    if len(poke_resp['types']) > 1:
        secondary_type = poke_resp['types'][1]['type']['name']
    else:
        secondary_type = 'none'
    
    return [poke_id,poke_name,primary_type,secondary_type]

# %%
# Let's test our function on the 3 original starter pokemon
original_starter_ids = list(range(1,10, 3))
print(original_starter_ids)
# Out:
# [1, 4, 7]

# %%
for poke_id in original_starter_ids:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    print(details)
# Out:
# [1, 'bulbasaur', 'grass', 'poison']
# [4, 'charmander', 'fire', 'none']
# [7, 'squirtle', 'water', 'none']

# %% [markdown]
# ### Moving to Pandas
#
# Let's get all of these details for all of the original 151 pokemon! And save them to a Pandas dataframe.

# %%
# Need to import pandas
import pandas as pd

# %%
# Let's go ahead and define what our columns will be
col_names = ['id', 'name', 'primary_type', 'secondary_type']

# %%
col_names
# Out:
# ['id', 'name', 'primary_type', 'secondary_type']

# %%
# Define a list of our 151 pokemon ids
original_151 = list(range(1,152))

# %% [markdown]
# So we're going to make 151 requests... don't want to overload the API endpoint! So let's use the time library to space out our requests.

# %%
import time

# %%
# Easiest way to do this will be to have a list of lists, then concat them all

# Define a blank list to capture all the pokemon details
row_list = []

# And then loop over our pokemon ids!
for poke_id in original_151:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    row_list.append(details)
    time.sleep(0.5)
    
# Then, concat everything into one df
# Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html
poke_df = pd.concat([pd.DataFrame([i], columns = col_names) for i in row_list], ignore_index=True)

# %%
poke_df
# Out:
#       id        name primary_type secondary_type
# 0      1   bulbasaur        grass         poison
# 1      2     ivysaur        grass         poison
# 2      3    venusaur        grass         poison
# 3      4  charmander         fire           none
# 4      5  charmeleon         fire           none
# ..   ...         ...          ...            ...
# 146  147     dratini       dragon           none
# 147  148   dragonair       dragon           none
# 148  149   dragonite       dragon         flying
# 149  150      mewtwo      psychic           none
# 150  151         mew      psychic           none
#
# [151 rows x 4 columns]

# %%
# visualize it!
import matplotlib.pyplot as plt

primary_type_count = poke_df.groupby('primary_type').count()['id'].sort_values(ascending=False)

plt.figure(figsize=(10,8))
plt.bar(primary_type_count.index, primary_type_count)

plt.title("Counts of Pokemon Primary Types")
plt.ylabel("Number of Pokemon")
plt.xlabel("Primary Type")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ![monty python gif - and now for something completely different, from giphy](https://media.giphy.com/media/xznyPebL28X5u/giphy.gif)

# %% [markdown]
# # Movie Time!
#
# Let's practice with an API that actually requires some authorization, in the form of an API Key!
#
# https://www.themoviedb.org/documentation/api

# %% [markdown]
# # **NEVER EVER PUT YOUR API KEY ON GITHUB**
#
# Either create a json file with API keys in a different directory, or create a python file with the key saved as a variable that you can call. (There are even more options than that, but these are two easily-accessible ones)

# %%
# Option 1: use a json file saved to some other folder outside your Git repo
# You can make a secrets folder on your ~ directory!
# In a new terminal window, create a file called api.json and save the path to that file

# Need to import json to do this
import json

# Quick helper function to open the json
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# Using the function to open and load all keys in that file 
api_keys = get_keys("/Users/lberlin/secrets/api.json")

# Setting the first (and only) value as a variable
tmdb_key_1 = api_keys['tmdb_key']

# %%
# Option 2: use a python file that's been added to your .gitignore

# In a new terminal window, create a file called keys.py in this repo
# Save the api key as tmdb_api_key = "[key]"

from keys import tmdb_api_key

tmdb_key_2 = tmdb_api_key

# Then let's edit our .gitignore file together

# %% [markdown]
# Just as important! You may want to call the variable you've set to check that the API key is rendering correctly - but **be sure to clear the output of that cell** or else the output will show your key! And then if you push to GitHub it'll push that output to the internet which defeats the whole point of saving your key elsewhere!

# %% [markdown]
# ### And now, accessing movie data
#
# Documentation: https://developers.themoviedb.org/3

# %%
# Default URL given as an example... let's see what it is!
test_url = f"https://api.themoviedb.org/3/movie/550?api_key={tmdb_key_1}"

# %%
test_resp = requests.get(test_url).json()

# %%
test_resp.keys()

# %%
# Find similar movies to the previous id
fight_club_id = 550
similar_url = f"https://api.themoviedb.org/3/movie/{fight_club_id}/similar?api_key={tmdb_key_1}"
similar_resp = requests.get(similar_url).json()

# %%
similar_resp.keys()

# %%
# How many similar movies did it find?
similar_resp['total_results']

# %%
# but is that the length of these results?
len(similar_resp['results'])

# %%
# what's in here?
for res in similar_resp['results']:
    print(res['title'])

# %% [markdown]
# ## Level Up: Another Way to Deal with APIs
#
# Check out [Postman](https://www.getpostman.com/).

# %% [markdown]
# ## Extra Credit: Further Practice
#
# There are many ways to access data through APIs! [Sodapy](https://github.com/xmunoz/sodapy) is the Python client for the Socrata Open Data API.

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! No credit cards required!

# %%
token = '' # paste your token here 

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)

# %%
len(results)

# %%
results[0]

# %%
df_soda = pd.DataFrame(results)

print(len(df_soda))
print(df_soda.columns)
df_soda.head()

# %% [markdown]
# ## Even Further Practice
#
# https://github.com/toddmotto/public-apis
#
# Find a buddy, find a free api, get a key, and do a GET. Try to transform the response into a dataframe.
